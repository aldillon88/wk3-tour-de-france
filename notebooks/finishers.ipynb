# %%
import pandas as pd
from functions import trim_and_lower, extract_string_in_parentheses, time_parts
import re
from datetime import timedelta
import yaml

# %%
try:
    with open("../config.yaml", "r") as file:
        config = yaml.safe_load(file)
except:
    print("The configuration file was not found!")

# %%
path = config['data']['raw']['raw_1']
df = pd.read_csv(path)

# %%
df = trim_and_lower(df)

# %% [markdown]
# Problems:
# - time wasn't recorded or was lost for years 1905 to 1912
# - over 2000 rows include values where the finishing time was only minutes or seconds behind the winner
# - finding the winning time was difficult for years where the winner was dsq, because their ranking was no longer "1"

# %%
df["time_parts"] = df.time.apply(lambda x: pd.Series([time_parts(x)]))

# %%
w = df.drop_duplicates(subset="year", keep='first')

cols_to_drop = [
    "rank",
    "rider",
    "team",
    "time"
]

w = w.drop(columns=cols_to_drop).set_index("year")
w.rename(columns={'time_parts': 'winning_time_parts'}, inplace=True)

# %%
df = df.join(w, on="year", how='left', lsuffix="_x")
df.head()
# Out:
#    year rank                     rider          time          team  \
# 0  1903    1       maurice garin (fra)   94h 33' 14"  la française
# 1  1903    2      lucien pothier (fra)  + 2h 59' 21"  la française
# 2  1903    3    fernand augereau (fra)  + 4h 29' 24"  la française
# 3  1903    4  rodolfo muller[27] (ita)  + 4h 39' 30"  la française
# 4  1903    5        jean fischer (fra)  + 4h 58' 44"  la française
#
#      time_parts winning_time_parts
# 0  [94, 33, 14]       [94, 33, 14]
# 1   [2, 59, 21]       [94, 33, 14]
# 2   [4, 29, 24]       [94, 33, 14]
# 3   [4, 39, 30]       [94, 33, 14]
# 4   [4, 58, 44]       [94, 33, 14]

# %%
df['finishing_time_parts'] = df.apply(lambda row: row['time_parts'] if row['time_parts'] == row['winning_time_parts'] else [a + b for a, b in zip(row['time_parts'], row['winning_time_parts'])], axis=1)
df.rename(columns={"time_parts": "margin"}, inplace=True)
df['margin'] = df.apply(lambda row: [0, 0, 0] if row['margin'] == row['winning_time_parts'] else row["margin"], axis=1)
df
# Out:
#       year rank                              rider          time  \
# 0     1903    1                maurice garin (fra)   94h 33' 14"
# 1     1903    2               lucien pothier (fra)  + 2h 59' 21"
# 2     1903    3             fernand augereau (fra)  + 4h 29' 24"
# 3     1903    4           rodolfo muller[27] (ita)  + 4h 39' 30"
# 4     1903    5                 jean fischer (fra)  + 4h 58' 44"
# ...    ...  ...                                ...           ...
# 9890  2022  130              frederik frison (bel)  + 5h 30' 19"
# 9891  2022  131  reinardt janse van rensburg (rsa)  + 5h 31' 25"
# 9892  2022  132        amund grøndahl jansen (nor)  + 5h 31' 27"
# 9893  2022  133                albert torres (esp)  + 5h 36' 33"
# 9894  2022  134                   caleb ewan (aus)  + 5h 40' 42"
#
#                          team       margin winning_time_parts  \
# 0                la française    [0, 0, 0]       [94, 33, 14]
# 1                la française  [2, 59, 21]       [94, 33, 14]
# 2                la française  [4, 29, 24]       [94, 33, 14]
# 3                la française  [4, 39, 30]       [94, 33, 14]
# 4                la française  [4, 58, 44]       [94, 33, 14]
# ...                       ...          ...                ...
# 9890             lotto–soudal  [5, 30, 19]       [79, 33, 20]
# 9891             lotto–soudal  [5, 31, 25]       [79, 33, 20]
# 9892  team bikeexchange–jayco  [5, 31, 27]       [79, 33, 20]
# 9893            movistar team  [5, 36, 33]       [79, 33, 20]
# 9894             lotto–soudal  [5, 40, 42]       [79, 33, 20]
#
#      finishing_time_parts
# 0            [94, 33, 14]
# 1            [96, 92, 35]
# 2            [98, 62, 38]
# 3            [98, 72, 44]
# 4            [98, 91, 58]
# ...                   ...
# 9890         [84, 63, 39]
# 9891         [84, 64, 45]
# 9892         [84, 64, 47]
# 9893         [84, 69, 53]
# 9894         [84, 73, 62]
#
# [9895 rows x 8 columns]

# %%
#df["time_parts"] = df.time.apply(lambda x: pd.Series([time_parts(x)]))

df["country"] = df.rider.apply(lambda x: pd.Series([extract_string_in_parentheses(x)]))
df
# Out:
#       year rank                              rider          time  \
# 0     1903    1                maurice garin (fra)   94h 33' 14"
# 1     1903    2               lucien pothier (fra)  + 2h 59' 21"
# 2     1903    3             fernand augereau (fra)  + 4h 29' 24"
# 3     1903    4           rodolfo muller[27] (ita)  + 4h 39' 30"
# 4     1903    5                 jean fischer (fra)  + 4h 58' 44"
# ...    ...  ...                                ...           ...
# 9890  2022  130              frederik frison (bel)  + 5h 30' 19"
# 9891  2022  131  reinardt janse van rensburg (rsa)  + 5h 31' 25"
# 9892  2022  132        amund grøndahl jansen (nor)  + 5h 31' 27"
# 9893  2022  133                albert torres (esp)  + 5h 36' 33"
# 9894  2022  134                   caleb ewan (aus)  + 5h 40' 42"
#
#                          team       margin winning_time_parts  \
# 0                la française    [0, 0, 0]       [94, 33, 14]
# 1                la française  [2, 59, 21]       [94, 33, 14]
# 2                la française  [4, 29, 24]       [94, 33, 14]
# 3                la française  [4, 39, 30]       [94, 33, 14]
# 4                la française  [4, 58, 44]       [94, 33, 14]
# ...                       ...          ...                ...
# 9890             lotto–soudal  [5, 30, 19]       [79, 33, 20]
# 9891             lotto–soudal  [5, 31, 25]       [79, 33, 20]
# 9892  team bikeexchange–jayco  [5, 31, 27]       [79, 33, 20]
# 9893            movistar team  [5, 36, 33]       [79, 33, 20]
# 9894             lotto–soudal  [5, 40, 42]       [79, 33, 20]
#
#      finishing_time_parts country
# 0            [94, 33, 14]     fra
# 1            [96, 92, 35]     fra
# 2            [98, 62, 38]     fra
# 3            [98, 72, 44]     ita
# 4            [98, 91, 58]     fra
# ...                   ...     ...
# 9890         [84, 63, 39]     bel
# 9891         [84, 64, 45]     rsa
# 9892         [84, 64, 47]     nor
# 9893         [84, 69, 53]     esp
# 9894         [84, 73, 62]     aus
#
# [9895 rows x 9 columns]

# %%
#display(df.loc[df.time.isna()])
#display(df.loc[df.time_parts.isna()])
#display(df.loc[df.winning_time_parts.isna()])

# %%
# Save the DataFrame to a new CSV file with 'utf-8' encoding
output_file_path = config['data']['clean']['clean_1']
df.to_csv(output_file_path, encoding='utf-8', index=False)
